-- %%
USE Estudiantes;
-- Out:
-- Los comandos se han completado correctamente.
-- Tiempo total de ejecución: 00:00:00.005

-- %%
SELECT * FROM DESERCIONES_CANCELACIÓN_DE_MATRÍCULA;
-- Out:
-- (1110 filas afectadas)
-- Tiempo total de ejecución: 00:00:00.062
-- ...
